# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Data/iphone_mobile_sales.csv")
df.head()
# Out:
#      OrderID         OrderDate           Region       City             Store  \
# 0  ORD-00504  2023-01-02 23:34            India       Pune          Best Buy
# 1  ORD-00232  2023-01-03 11:12  South East Asia        NaN           Walmart
# 2  ORD-00499  2023-01-04 22:33            India  Ahmedabad        JD Central
# 3  ORD-00506  2023-01-06 20:14    North America        NaN  Reliance Digital
# 4  ORD-00783  2023-01-09 07:39    North America        NaN    Apple Reseller
#
#           SalesChannel   CustomerID              Model            Variant  \
# 0               Retail  CUST-930910      iPhone 16 Pro     512GB/Midnight
# 1               Retail  CUST-259608          iPhone 15     256GB/Midnight
# 2               Retail  CUST-535165  iPhone 15 Pro Max        256GB/Black
# 3               Retail  CUST-184141  iPhone 14 Pro Max     256GB/Midnight
# 4  Authorized Reseller  CUST-795891     iPhone 15 Plus  256GB/Space Black
#
# ...

# %%
df.count()
# Out:
# OrderID           1000
# OrderDate         1000
# Region            1000
# City               163
# Store             1000
# SalesChannel      1000
# CustomerID        1000
# Model             1000
# Variant           1000
# Color             1000
# StorageGB         1000
# WarrantyMonths    1000
# Serial            1000
# PaymentMethod     1000
# ListPrice         1000
# DiscountPct       1000
# DiscountAmount    1000
# FinalUnitPrice    1000
# Quantity          1000
# TotalAmount       1000
# SalesRep          1000
# dtype: int64

# %%
df['FinalUnitPrice'].max()
# Out:
# 1871.45

# %%
df['FinalUnitPrice'].min()
# Out:
# 374.43

# %%
df[df['FinalUnitPrice']==1871.45]
# Out:
#       OrderID         OrderDate  Region City  Store SalesChannel   CustomerID  \
# 13  ORD-00815  2023-01-21 09:04  Africa  NaN  Croma       Retail  CUST-901145
#
#           Model             Variant        Color  ...  WarrantyMonths  \
# 13  iPad Pro 13  1024GB/Space Black  Space Black  ...              12
#
#              Serial PaymentMethod ListPrice  DiscountPct  DiscountAmount  \
# 13  553797952540CQA    Debit Card   1883.55         0.64            12.1
#
#     FinalUnitPrice  Quantity  TotalAmount  SalesRep
# 13         1871.45         3      5614.35  A. Kumar
#
# [1 rows x 21 columns]

# %%
df[df['FinalUnitPrice']==374.43]
# Out:
#        OrderID         OrderDate  Region City     Store SalesChannel  \
# 510  ORD-00778  2024-07-01 05:16  Europe  NaN  Best Buy       Online
#
#       CustomerID                Model           Variant        Color  ...  \
# 510  CUST-392749  iPhone SE (3rd Gen)  64GB/Space Black  Space Black  ...
#
#      WarrantyMonths           Serial PaymentMethod ListPrice  DiscountPct  \
# 510              12  527952898924CHJ          Cash     429.0        12.72
#
#      DiscountAmount  FinalUnitPrice  Quantity  TotalAmount  SalesRep
# 510           54.57          374.43         2       748.86  E. Brown
#
# [1 rows x 21 columns]

# %%
df[df['FinalUnitPrice']<=1000]
# Out:
#        OrderID         OrderDate           Region City            Store  \
# 1    ORD-00232  2023-01-03 11:12  South East Asia  NaN          Walmart
# 6    ORD-00756  2023-01-10 03:05           Europe  NaN            Jumia
# 8    ORD-00526  2023-01-13 05:38           Europe  NaN  Flipkart Online
# 9    ORD-00170  2023-01-13 16:44      Middle East  NaN    Amazon Online
# 11   ORD-00631  2023-01-18 21:50      Middle East  NaN   Apple Reseller
# ..         ...               ...              ...  ...              ...
# 991  ORD-00309  2025-11-17 07:28  South East Asia  NaN           Lazada
# 992  ORD-00645  2025-11-18 12:51    Latin America  NaN   Apple Reseller
# 994  ORD-00183  2025-11-21 03:29           Europe  NaN      Apple Store
# 997  ORD-00618  2025-11-30 09:06    Latin America  NaN      Apple Store
# 999  ORD-00396  2025-11-30 19:14      Middle East  NaN             Noon
#
#     SalesChannel   CustomerID                Model            Variant  \
# ...

# %%
df[df['FinalUnitPrice']>=1000]
# Out:
#        OrderID         OrderDate         Region       City             Store  \
# 0    ORD-00504  2023-01-02 23:34          India       Pune          Best Buy
# 2    ORD-00499  2023-01-04 22:33          India  Ahmedabad        JD Central
# 3    ORD-00506  2023-01-06 20:14  North America        NaN  Reliance Digital
# 4    ORD-00783  2023-01-09 07:39  North America        NaN    Apple Reseller
# 5    ORD-00988  2023-01-09 12:03  North America        NaN    Apple Reseller
# ..         ...               ...            ...        ...               ...
# 989  ORD-00615  2025-11-14 19:15  North America        NaN        eBay Store
# 993  ORD-00442  2025-11-20 13:17          India    Lucknow       Apple Store
# 995  ORD-00763  2025-11-21 05:18          India      Surat   Flipkart Online
# 996  ORD-00447  2025-11-24 19:09  North America        NaN            Lazada
# 998  ORD-00861  2025-11-30 10:28  North America        NaN     Amazon Online
#
# ...

# %%
list[(df['Model'])]
# Out:
# list[0          iPhone 16 Pro
# 1              iPhone 15
# 2      iPhone 15 Pro Max
# 3      iPhone 14 Pro Max
# 4         iPhone 15 Plus
#              ...
# 995       iPhone 15 Plus
# 996    iPhone 16 Pro Max
# 997            iPhone 16
# 998          iPad Pro 13
# 999            iPhone 14
# Name: Model, Length: 1000, dtype: object]

# %%
list(df['Model'])[999]
# Out:
# 'iPhone 14'

# %%
list(df['Model'])[0][0:6]
# Out:
# 'iPhone'

# %%
list(df['Model'])[0][0:6].upper()
# Out:
# 'IPHONE'

# %%
list(df['Model'])[0][0:6].lower()
# Out:
# 'iphone'

# %%
list(df['Model'])[999].strip()
# Out:
# 'iPhone 14'

# %%
df['Brand']=df['Model']

# %%
df.head()
# Out:
#      OrderID         OrderDate           Region       City             Store  \
# 0  ORD-00504  2023-01-02 23:34            India       Pune          Best Buy
# 1  ORD-00232  2023-01-03 11:12  South East Asia        NaN           Walmart
# 2  ORD-00499  2023-01-04 22:33            India  Ahmedabad        JD Central
# 3  ORD-00506  2023-01-06 20:14    North America        NaN  Reliance Digital
# 4  ORD-00783  2023-01-09 07:39    North America        NaN    Apple Reseller
#
#           SalesChannel   CustomerID              Model            Variant  \
# 0               Retail  CUST-930910      iPhone 16 Pro     512GB/Midnight
# 1               Retail  CUST-259608          iPhone 15     256GB/Midnight
# 2               Retail  CUST-535165  iPhone 15 Pro Max        256GB/Black
# 3               Retail  CUST-184141  iPhone 14 Pro Max     256GB/Midnight
# 4  Authorized Reseller  CUST-795891     iPhone 15 Plus  256GB/Space Black
#
# ...

# %%
df.sort_values(by=['Color'])
# Out:
#        OrderID         OrderDate           Region    City             Store  \
# 720  ORD-00203  2025-02-08 21:40           Europe     NaN       Apple Store
# 84   ORD-00863  2023-04-06 21:32  South East Asia     NaN            Lazada
# 564  ORD-00489  2024-08-29 13:12            India  Indore     Amazon Online
# 246  ORD-00256  2023-09-29 04:14  South East Asia     NaN        JD Central
# 562  ORD-00652  2024-08-29 02:43      Middle East     NaN            Lazada
# ..         ...               ...              ...     ...               ...
# 905  ORD-00143  2025-08-18 09:01           Europe     NaN  Reliance Digital
# 904  ORD-00519  2025-08-17 00:06  South East Asia     NaN       Apple Store
# 714  ORD-00849  2025-02-02 05:35    Latin America     NaN            Lazada
# 404  ORD-00046  2024-03-18 02:17    North America     NaN  Reliance Digital
# 458  ORD-00035  2024-05-15 15:16           Europe     NaN   Flipkart Online
#
# ...

# %%
df.sort_values(by=['Variant'],ascending=False)
# Out:
#        OrderID         OrderDate           Region     City             Store  \
# 9    ORD-00170  2023-01-13 16:44      Middle East      NaN     Amazon Online
# 41   ORD-00674  2023-02-19 23:25           Europe      NaN          Best Buy
# 20   ORD-00315  2023-01-26 21:26    North America      NaN            Target
# 793  ORD-00732  2025-05-02 19:13           Africa      NaN              Noon
# 104  ORD-00905  2023-05-01 11:14          Oceania      NaN     Amazon Online
# ..         ...               ...              ...      ...               ...
# 110  ORD-00344  2023-05-05 07:10            India  Kolkata          Best Buy
# 425  ORD-00802  2024-04-06 13:02        East Asia      NaN  Reliance Digital
# 963  ORD-00105  2025-10-16 21:18  South East Asia      NaN     Amazon Online
# 121  ORD-00734  2023-05-22 03:41    North America      NaN           Walmart
# 401  ORD-00274  2024-03-14 16:24  South East Asia      NaN            Target
#
# ...

# %%
df.sort_values(by=['CustomerID'],ascending=False)
# Out:
#        OrderID         OrderDate           Region    City             Store  \
# 592  ORD-00987  2024-09-29 12:52            India    Pune           Walmart
# 593  ORD-00606  2024-09-30 06:53  South East Asia     NaN     Amazon Online
# 111  ORD-00952  2023-05-05 18:23    Latin America     NaN          Best Buy
# 211  ORD-00650  2023-08-26 10:54            India   Delhi  Reliance Digital
# 923  ORD-00291  2025-09-04 11:32          Oceania     NaN        eBay Store
# ..         ...               ...              ...     ...               ...
# 458  ORD-00035  2024-05-15 15:16           Europe     NaN   Flipkart Online
# 564  ORD-00489  2024-08-29 13:12            India  Indore     Amazon Online
# 80   ORD-00077  2023-04-04 00:03           Europe     NaN           Walmart
# 598  ORD-00387  2024-10-08 13:51    Latin America     NaN        JD Central
# 199  ORD-00754  2023-08-12 19:59           Africa     NaN             Croma
#
# ...
